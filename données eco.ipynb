# %%
import requests
import pandas as pd

# URL de l'API
url = "https://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD?date=1970:2020&format=json"

# Requête GET à l'API
req = requests.get(url)
data_eco = req.json()

# Vérification des données
if len(data) > 1 and "indicator" in data[1][0]:
    # Extraction des données utiles
    records = data_eco[1]
    
    # Transformation des données en DataFrame pandas
    df = pd.DataFrame(records)

    # Affichage de colonnes pertinentes
    table = df[["date", "value", "indicator", "country"]]
    print(table)
else:
    print("Les données retournées ne contiennent pas les informations attendues.")
# Out:
#     date         value                                          indicator  \
# 0   2020  9.290741e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1   2019  1.006527e+12  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2   2018  1.012719e+12  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3   2017  9.401055e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4   2016  8.298300e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 5   2015  8.992957e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 6   2014  9.796897e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 7   2013  9.633473e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 8   2012  9.526756e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 9   2011  9.454391e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 10  2010  8.494097e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 11  2009  7.154853e+11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# ...
