# %% [markdown]
# Installation des bibliothèques requises

# %%
# %pip install requests
# %pip install Faostat
# Out:
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB 3.6 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.0-cp310-cp310-win_amd64.whl (102 kB)
#      -------------------------------------- 102.2/102.2 kB 3.0 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#      -------------------------------------- 126.3/126.3 kB 2.5 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#      -------------------------------------- 167.3/167.3 kB 3.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ---------------------------------------- 70.4/70.4 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.8.30 charset-normalizer-3.4.0 idna-3.10 requests-2.32.3 urllib3-2.2.3
# [notice] A new release of pip available: 22.2.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting Faostat
#   Downloading faostat-1.1.2-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: requests in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from Faostat) (2.32.3)
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 4.7 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      ------------------------------------- 508.0/508.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from pandas->Faostat) (2.8.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from pandas->Faostat) (1.23.3)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      ------------------------------------- 346.6/346.6 kB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from requests->Faostat) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from requests->Faostat) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from requests->Faostat) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from requests->Faostat) (2.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\phili\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->Faostat) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas, Faostat
# Successfully installed Faostat-1.1.2 pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# [notice] A new release of pip available: 22.2.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Obtention de l'API de My GFW

# %%
import requests

# URL de l'API
url = 'https://data-api.globalforestwatch.org/auth/token'

# Données à envoyer dans la requête POST
data = {
    'username': 'philippe.detinguy@ensae.fr',
    'password': 'Philgfw1'
}

# En-têtes de la requête
headers = {
    'Content-Type': 'application/x-www-form-urlencoded'
}

# Envoi de la requête POST
response = requests.post(url, data=data, headers=headers)

# Vérification de la réponse
if response.status_code == 200:
    print('Succès:', response.json())
else:
    print(f'Erreur: {response.status_code}, {response.text}')

response.json()["data"]['access_token']
# Out:
# Succès: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjY3NDU4MTkzNTlhMzhlYmRiMTZkN2YzYyIsInJvbGUiOiJVU0VSIiwicHJvdmlkZXIiOiJsb2NhbCIsImVtYWlsIjoicGhpbGlwcGUuZGV0aW5ndXlAZW5zYWUuZnIiLCJleHRyYVVzZXJEYXRhIjp7ImFwcHMiOlsicnciXX0sImNyZWF0ZWRBdCI6MTczMzU2ODcwMTQ0NCwiaWF0IjoxNzMzNTY4NzAxfQ.RsI-_EI5lRrSz57nEEUGar7rMf7WIYhgkKZtT-IVcyI', 'token_type': 'bearer'}, 'status': 'success'}
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjY3NDU4MTkzNTlhMzhlYmRiMTZkN2YzYyIsInJvbGUiOiJVU0VSIiwicHJvdmlkZXIiOiJsb2NhbCIsImVtYWlsIjoicGhpbGlwcGUuZGV0aW5ndXlAZW5zYWUuZnIiLCJleHRyYVVzZXJEYXRhIjp7ImFwcHMiOlsicnciXX0sImNyZWF0ZWRBdCI6MTczMzU2ODcwMTQ0NCwiaWF0IjoxNzMzNTY4NzAxfQ.RsI-_EI5lRrSz57nEEUGar7rMf7WIYhgkKZtT-IVcyI'

# %% [markdown]
# Tentative d'obtention de l'API de la FAO :

# %%
import requests

def test():
    # (1) Requête GET
    # Basé sur un exemple de FAOSTAT (http://faostat.github.io/faostat-api/)
    get_url = 'http://fenixapps2.fao.org/api/v1.0/en/classifications/QC'
    try:
        response = requests.get(get_url)
        response.raise_for_status()  # Lève une exception pour les erreurs HTTP (ex : 404, 500)
        print("Réponse GET des métadonnées :")
        print(response.json())  # Affiche la réponse JSON
    except requests.exceptions.RequestException as e:
        print(f"Erreur lors de la requête GET : {e}")

    # (2) Requête POST
    post_url = "http://fenixapps2.fao.org/api/v1.0/en/data"
    data = {
        "datasource": "production",  # test
        "output_type": "objects",  # tableaux
        "api_key": "n.a.",
        "client_key": "n.a.",
        "lang": "en",
        "domain_codes": ["QC"],
        "decimal_places": "2",
        "List1Codes": ["33"],
        "List2Codes": ["2510"],
        "List3Codes": ["15"],
        "List4Codes": ["2007", "2008", "2009", "2010", "2011", "2012"],
        "List5Codes": ["null"],
        "List6Codes": ["null"],
        "List7Codes": ["null"],
        "null_values": True,
        "page_size": "100",
        "limit": "10",
        "page_number": "1"
    }

    try:
        response = requests.post(post_url, json=data)  # Envoie des données au format JSON
        response.raise_for_status()  # Vérifie les erreurs dans la réponse
        print("Réponse POST des données :")
        print(response.url)  # Affiche l'URL complète avec les paramètres de requête
        print(response.json())  # Affiche la réponse JSON
    except requests.exceptions.RequestException as e:
        print(f"Erreur lors de la requête POST : {e}")

if __name__ == "__main__":
    test()
# Out:
# Erreur lors de la requête GET : 503 Server Error: Service Temporarily Unavailable for url: http://fenixapps2.fao.org/api/v1.0/en/classifications/QC
# Erreur lors de la requête POST : 503 Server Error: Service Temporarily Unavailable for url: http://fenixapps2.fao.org/api/v1.0/en/data

# %% [markdown]
# Nous remarquons que la FAO n'a pas d'API disponible en ce moment. Nous allons donc utiliser le package python "faostats" qui nous donne accès à ses données directement comme si nous faisions l'API nous mêmes. Les données doivent être traitées au même titre que si nous utilisions l'API (section de code à part pour le traitement de ces données).

# %%
import faostat
faostat.list_datasets()
# Out:
# [('code',
#   'label',
#   'date_update',
#   'note_update',
#   'release_current',
#   'state_current',
#   'year_current',
#   'release_next',
#   'state_next',
#   'year_next'),
#  ('QCL',
#   'Crops and livestock products',
#   '2024-10-07',
#   'minor revision',
#   '2023-12-23 / 2024-10-07',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('QI',
#   'Production Indices',
#   '2024-03-13',
#   '',
#   '2024-03-13',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('QV',
#   'Value of Agricultural Production',
#   '2024-03-13',
#   '',
#   '2024-03-13',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('FS',
#   'Suite of Food Security Indicators',
#   '2024-07-25',
#   'minor revision',
#   '2024-07-24 / 2024-07-25',
#   'final',
#   '2023',
#   '2025-07',
#   'final',
#   '2024'),
#  ('FBS',
#   'Food Balances (2010-)',
#   '2024-07-19',
#   '',
#   '2024-07-19',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('SCL',
#   'Supply Utilization Accounts (2010-)',
#   '2024-07-19',
#   '',
#   '2024-07-19',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('CB',
#   'Commodity Balances (non-food) (2010-)',
#   '2024-07-19',
#   '',
#   '2024-07-19',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('FBSH',
#   'Food Balances (-2013, old methodology and population)',
#   '2023-03-10',
#   'minor revision',
#   '2016-12-20 / 2023-03-10',
#   'final',
#   '2013',
#   '',
#   '',
#   ''),
#  ('CBH',
#   'Commodity Balances (non-food) (-2013, old methodology)',
#   '2021-12-03',
#   'minor revision',
#   '2016-12-20 / 2021-12-03',
#   'final',
#   '2013',
#   '',
#   'final',
#   ''),
#  ('TCL',
#   'Crops and livestock products',
#   '2023-12-21',
#   '',
#   '2023-12-21',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('TM',
#   'Detailed trade matrix',
#   '2023-12-21',
#   '',
#   '2023-12-21',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('TI',
#   'Trade Indices',
#   '2023-12-21',
#   '',
#   '2023-12-21',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('PP',
#   'Producer Prices',
#   '2024-01-09',
#   '',
#   '2024-01-09',
#   'final',
#   '2023',
#   '2024-12',
#   'final',
#   '2024'),
#  ('CP',
#   'Consumer Price Indices',
#   '2024-11-11',
#   '',
#   '2024-11-11',
#   'preliminary',
#   '2024',
#   '2025-01',
#   'preliminary',
#   '2024'),
#  ('PD',
#   'Deflators',
#   '2024-06-12',
#   '',
#   '2024-06-12',
#   'preliminary',
#   '2023',
#   '2024-10',
#   'final',
#   '2023'),
#  ('PE',
#   'Exchange rates',
#   '2024-11-05',
#   '',
#   '2024-11-05',
#   'final',
#   '2024',
#   '2025-01',
#   'final',
#   '2024'),
#  ('CAHD',
#   'Cost and Affordability of a Healthy Diet (CoAHD)',
#   '2024-07-24',
#   '',
#   '2024-07-24',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('SUA',
#   'Availability (based on supply utilization accounts)',
#   '2024-12-04',
#   '',
#   '2024-12-04',
#   'final',
#   '2021',
#   '2025-09',
#   'final',
#   '2022'),
#  ('HCES',
#   'Apparent intake (based on household consumption and expenditure surveys)',
#   '2024-12-04',
#   '',
#   '2024-12-04',
#   'final',
#   '',
#   '2025-09',
#   'final',
#   ''),
#  ('FDIQ',
#   'Intake (based on individual quantitative dietary surveys)',
#   '2024-12-04',
#   '',
#   '2024-12-04',
#   'final',
#   '',
#   '2024-09',
#   'final',
#   ''),
#  ('MDDW',
#   'Diversity (MDD-W, based on individual qualitative dietary surveys)',
#   '2024-12-04',
#   '',
#   '2024-12-04',
#   'final',
#   '',
#   '2025-09',
#   'final',
#   ''),
#  ('RL',
#   'Land Use',
#   '2024-08-19',
#   'minor revision',
#   '2024-07-04 / 2024-08-19',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('LC',
#   'Land Cover',
#   '2024-07-04',
#   '',
#   '2024-07-04',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('RFN',
#   'Fertilizers by Nutrient',
#   '2024-07-17',
#   '',
#   '2024-07-17',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('RFB',
#   'Fertilizers by Product',
#   '2024-07-17',
#   '',
#   '2024-07-17',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('RFM',
#   'Detailed trade matrix (fertilizers)',
#   '2024-07-17',
#   '',
#   '2024-07-17',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('EMN',
#   'Livestock Manure',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('RP',
#   'Pesticides Use',
#   '2024-09-26',
#   'minor revision',
#   '2024-07-16 / 2024-09-26',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('RT',
#   'Pesticides Trade',
#   '2024-09-23',
#   'minor revision',
#   '2024-07-16 / 2024-09-23',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('ESB',
#   'Cropland Nutrient Balance',
#   '2024-11-27',
#   '',
#   '2024-11-27',
#   'final',
#   '2022',
#   '2025-11',
#   'final',
#   '2023'),
#  ('EK',
#   'Livestock Patterns',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('BE',
#   'Bioenergy',
#   '2024-08-28',
#   'minor revision',
#   '2024-06-17 / 2024-08-28',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('ET',
#   'Temperature change on land',
#   '2024-03-25',
#   '',
#   '2024-03-25',
#   'final',
#   '2023',
#   '2025-03',
#   'final',
#   '2024'),
#  ('OA',
#   'Annual population',
#   '2022-11-10',
#   '',
#   '2022-11-10',
#   'preliminary',
#   '2021',
#   '',
#   'final',
#   '2022'),
#  ('OEA',
#   'Employment Indicators: Agriculture and agrifood systems',
#   '2024-11-14',
#   'minor revision',
#   '2024-10-24 / 2024-11-14',
#   'final',
#   '2023',
#   '2025-04',
#   'final',
#   '2024'),
#  ('OER',
#   'Employment Indicators: Rural',
#   '2024-10-24',
#   '',
#   '2024-10-24',
#   'final',
#   '2023',
#   '2025-04',
#   'final',
#   '2024'),
#  ('IG',
#   'Government Expenditure',
#   '2024-02-06',
#   '',
#   '2024-02-06',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('IC',
#   'Credit to Agriculture',
#   '2023-12-21',
#   '',
#   '2023-12-21',
#   'final',
#   '2022',
#   '2024-11',
#   'final',
#   '2023'),
#  ('EA',
#   'Development Flows to Agriculture',
#   '2024-11-15',
#   '',
#   '2024-11-15',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('FDI',
#   'Foreign Direct Investment (FDI)',
#   '2023-12-27',
#   '',
#   '2023-12-27',
#   'final',
#   '2022',
#   '2024-11',
#   'final',
#   '2023'),
#  ('CISP',
#   'Country Investment Statistics Profile',
#   '2024-06-26',
#   '',
#   '2024-06-26',
#   'preliminary',
#   '2023',
#   '2024-10',
#   'preliminary',
#   '2023'),
#  ('MK',
#   'Macro Indicators',
#   '2024-06-12',
#   '',
#   '2024-06-12',
#   'preliminary',
#   '2023',
#   '2024-10',
#   'final',
#   '2023'),
#  ('CS',
#   'Capital Stock',
#   '2023-12-22',
#   '',
#   '2023-12-22',
#   'final',
#   '2022',
#   '2024-11',
#   'final',
#   '2023'),
#  ('GFDI',
#   'Value shares by industry and primary factors',
#   '2024-11-19',
#   '',
#   '2024-11-19',
#   'final',
#   '2021',
#   '',
#   'final',
#   ''),
#  ('GT',
#   'Emissions totals',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('EM',
#   'Emissions indicators',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('EI',
#   'Emissions intensities',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GCE',
#   'Emissions from Crops',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GLE',
#   'Emissions from Livestock',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GN',
#   'Emissions from Energy use in agriculture',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GF',
#   'Emissions from Forests',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2023',
#   '2025-10',
#   'final',
#   '2024'),
#  ('GI',
#   'Emissions from Fires',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GV',
#   'Emissions from Drained organic soils',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GPP',
#   'Emissions from pre and post agricultural production',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('FO',
#   'Forestry Production and Trade',
#   '2023-12-21',
#   '',
#   '2023-12-21',
#   'final',
#   '2022',
#   '2024-12',
#   'final',
#   '2023'),
#  ('SDGB',
#   'SDG Indicators',
#   '2024-09-18',
#   '',
#   '2024-09-18',
#   'final',
#   '2024',
#   '',
#   'final',
#   '2024'),
#  ('WCAD',
#   'Structural data from agricultural censuses',
#   '2024-05-23',
#   'minor revision',
#   '2024-03-21 / 2024-05-23',
#   'final',
#   '2020',
#   '2025-02',
#   'final',
#   '2020'),
#  ('FT',
#   'Forestry Trade Flows',
#   '2022-05-27',
#   'minor revision',
#   '2019-06-19 / 2022-05-27',
#   'final',
#   '2017',
#   '',
#   '',
#   ''),
#  ('HS',
#   'Indicators from Household Surveys (gender, area, socioeconomics)',
#   '2014-07-31',
#   '',
#   '2014-07-31',
#   'final',
#   '2014',
#   '',
#   '',
#   ''),
#  ('AF',
#   'ASTI-Researchers',
#   '2019-11-11',
#   '',
#   '2019-11-11',
#   'final',
#   '2016',
#   '',
#   'preliminary',
#   '2017'),
#  ('AE',
#   'ASTI-Expenditures',
#   '2019-11-11',
#   '',
#   '2019-11-11',
#   'final',
#   '2016',
#   '',
#   'preliminary',
#   '2017'),
#  ('FA',
#   'Food Aid Shipments (WFP)',
#   '2016-12-22',
#   '',
#   '2016-12-22',
#   'preliminary',
#   '2016',
#   '',
#   '',
#   ''),
#  ('RM',
#   'Machinery',
#   '2021-12-03',
#   'minor revision',
#   '2011-12-22 / 2021-12-03',
#   'final',
#   '2009',
#   '',
#   '',
#   ''),
#  ('RY',
#   'Machinery Archive',
#   '2021-12-03',
#   'minor revision',
#   '2006-12-31 / 2021-12-03',
#   'final',
#   '2005',
#   '',
#   '',
#   ''),
#  ('RA',
#   'Fertilizers archive',
#   '2020-09-08',
#   'minor revision',
#   '2013-12-31 / 2020-09-08',
#   'final',
#   '2002',
#   '',
#   '',
#   ''),
#  ('PA',
#   'Producer Prices (old series)',
#   '1991-12-31',
#   '',
#   '1991-12-31',
#   'final',
#   '1990',
#   '',
#   '',
#   '')]

# %% [markdown]
# Cependant, nous pouvons remarquer - cf le document "test de FAOSTAT" - que, tout comme l'API, le package FAOSTAT n'est plus mis à jour - et toutes les données sont vides actuellement. A la place, nous allons donc télécharger directement les données nécessaires sur le site de la FAO - en format CSV - avant de les traiter de cette manière.

# %% [markdown]
# Import des données économiques avec l'API de la Banque Mondiale (voir la doc sur https://datatopics.worldbank.org/world-development-indicators/)

# %% [markdown]
# Avant d'importer les variables dont nous avons besoin, il faut justement déterminer quelles sont ces variables. Une petite revue de littérature s'impose.
#
# idée: utiliser la variable "part de l'agriculture dans le PIB", "revenus de la déforestation" (si ça existe).
# Référence qui revient souvent: la courbe de kuznets environnementale
#
# Articles :
# - Andrée, B. P. J., Chamorro, A., Spencer, P., Koomen, E., & Dogo, H. (2019). Revisiting the relation between economic growth and the environment; a global assessment of deforestation, pollution and carbon emission. Renewable and Sustainable Energy Reviews, 114, 109221.)
#   - inverted U-shaped relations between per capita income and deforestation
#   - Poverty and income inequality correlate with higher deforestation
#   - agricultural GDP shares correlate with deforestation
# - López, R., & Galinato, G. I. (2005). Trade policies, economic growth, and the direct causes of deforestation. Land economics, 81(2), 145-169.
#   -  Economy-wide factors such as trade openness and economic growth explain an important portion of the variation in three key factors of deforestation: poverty, agricultural expansion, and road building.

# %% [markdown]
# Variables récupérées:
#
# - Indice de GINI : SI.POV.GINI
# - agricultural land (% of land area) : AG.LND.AGRI.ZS
# - forest area (% of land area): AG.LND.FRST.ZS
# - GDP (US$): NY.GDP.MKTP.CD
# - GDP GROWTH : NY.GDP.MKTP.KD.GZ

# %% [markdown]
# Nous allons récupérer les données de la Banque Mondiale de deux manières différentes : la première avec un seul indicateur (au choix) pour cibler, la seconde avec tous les indicateurs en même temps pour avoir une vue d'ensemble de ce qui est disponible.

# %%
import requests
import pandas as pd

# URL de base de l'API
base_url = "https://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD?date=1960:2024&format=json"

# Initialisation des variables
all_records = []
page = 1

# Requête initiale pour obtenir le nombre total de pages
url = f"{base_url}&page={page}"
req = requests.get(url)
data_eco = req.json()

# Vérification de la structure de la réponse et extraction du nombre total de pages
if len(data_eco) > 0 and isinstance(data_eco[0], dict) and "pages" in data_eco[0]:
    total_pages = data_eco[0]["pages"]
    print(f"Nombre total de pages : {total_pages}")
else:
    print("Impossible de déterminer le nombre de pages.")
    exit()

# Récupérer les données pour toutes les pages
while page <= total_pages:
    url = f"{base_url}&page={page}"
    req = requests.get(url)
    data_eco = req.json()

    # Vérification si des données existent pour cette page
    if len(data_eco) > 1 and isinstance(data_eco[1], list):
        all_records.extend(data_eco[1])  # Ajouter les données de la page actuelle
    page += 1  # Passer à la page suivante

# Transformation des données en DataFrame pandas
df = pd.DataFrame(all_records)

# Vérification et affichage des colonnes pertinentes
if "country" in df.columns and "date" in df.columns and "value" in df.columns:
    table = df[["date", "value", "country"]]
    print(table.head())  # Afficher les premières lignes du tableau
else:
    print("Les colonnes attendues ne sont pas disponibles dans les données récupérées.")
# Out:
# Nombre total de pages : 341
#    date         value                                            country
# 0  2023  1.236163e+12  {'id': 'ZH', 'value': 'Africa Eastern and Sout...
# 1  2022  1.183962e+12  {'id': 'ZH', 'value': 'Africa Eastern and Sout...
# 2  2021  1.086772e+12  {'id': 'ZH', 'value': 'Africa Eastern and Sout...
# 3  2020  9.290741e+11  {'id': 'ZH', 'value': 'Africa Eastern and Sout...
# 4  2019  1.006527e+12  {'id': 'ZH', 'value': 'Africa Eastern and Sout...

# %%
df
# Out:
#                                               indicator  \
# 0     {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1     {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2     {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3     {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4     {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# ...                                                 ...
# 2921  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2922  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2923  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2924  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2925  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                                 country countryiso3code  date  \
# 0     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2020
# 1     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2019
# 2     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2018
# 3     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2017
# 4     {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2016
# ...                                                 ...             ...   ...
# 2921                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2014
# 2922                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2013
# 2923                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2012
# 2924                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2011
# 2925                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE  2010
#
#              value unit obs_status  decimal
# 0     9.290741e+11                        0
# 1     1.006527e+12                        0
# 2     1.012719e+12                        0
# 3     9.401055e+11                        0
# 4     8.298300e+11                        0
# ...            ...  ...        ...      ...
# 2921  1.949552e+10                        0
# 2922  1.909102e+10                        0
# 2923  1.711485e+10                        0
# 2924  1.410192e+10                        0
# 2925  1.204166e+10                        0
#
# [2926 rows x 8 columns]

# %%
import requests
import pandas as pd

def fetch_worldbank_data(indicator, start_date="1960", end_date="2024"):
    """
    Récupère les données de la Banque Mondiale pour un indicateur donné.
    
    Args:
        indicator (str): Code de l'indicateur (ex. "NY.GDP.MKTP.CD").
        start_date (str): Année de début des données (par défaut "1960").
        end_date (str): Année de fin des données (par défaut "2024").
    
    Returns:
        pd.DataFrame: Tableau contenant les données récupérées, ou None en cas d'échec.
    """
    base_url = f"https://api.worldbank.org/v2/country/all/indicator/{indicator}?date={start_date}:{end_date}&format=json"
    all_records = []
    page = 1

    url = f"{base_url}&page={page}"
    req = requests.get(url)
    data_eco = req.json()

    if len(data_eco) > 0 and isinstance(data_eco[0], dict) and "pages" in data_eco[0]:
        total_pages = data_eco[0]["pages"]
        print(f"{indicator} - Nombre total de pages : {total_pages}")
    else:
        print(f"{indicator} - Impossible de déterminer le nombre de pages.")
        return None

    while page <= total_pages:
        url = f"{base_url}&page={page}"
        req = requests.get(url)
        data_eco = req.json()

        if len(data_eco) > 1 and isinstance(data_eco[1], list):
            all_records.extend(data_eco[1])
        page += 1

    df = pd.DataFrame(all_records)

    if "country" in df.columns and "date" in df.columns and "value" in df.columns:
        # Extraire le nom du pays depuis le dictionnaire dans la colonne 'country'
        df["country"] = df["country"].apply(lambda x: x["value"] if isinstance(x, dict) else x)
        table = df[["date", "value", "country"]]
        return table
    else:
        print(f"{indicator} - Les colonnes attendues ne sont pas disponibles.")
        return None

# Liste des indicateurs
indicators = {
    "NY.GDP.MKTP.CD": "PIB",
    "SI.POV.GINI": "GINI",
    "AG.LND.AGRI.ZS": "Part terres agricoles",
    "AG.LND.FRST.ZS": "Part terres foret",
}

# Récupérer les données pour chaque indicateur
data_frames = []
for indicator, name in indicators.items():
    data = fetch_worldbank_data(indicator, start_date="1960", end_date="2024")
    if data is not None:
        data["indicator"] = name  # Ajouter une colonne pour l'indicateur
        data_frames.append(data)

# Combiner toutes les données dans une table unique
merged_data = None
for df in data_frames:
    # Transformer la colonne 'value' pour avoir une colonne par indicateur
    indicator_name = df["indicator"].iloc[0]
    df = df.rename(columns={"value": indicator_name})
    df = df.drop(columns=["indicator"])
    if merged_data is None:
        merged_data = df
    else:
        merged_data = pd.merge(merged_data, df, on=["date", "country"], how="outer")

# Afficher le tableau final
print(merged_data.head())
# Out:
# NY.GDP.MKTP.CD - Nombre total de pages : 341
# SI.POV.GINI - Nombre total de pages : 341
# AG.LND.AGRI.ZS - Nombre total de pages : 341
# AG.LND.FRST.ZS - Nombre total de pages : 341
#    date           PIB                      country  GINI  \
# 0  1960           NaN                  Afghanistan   NaN
# 1  1960  2.121696e+10  Africa Eastern and Southern   NaN
# 2  1960  1.188413e+10   Africa Western and Central   NaN
# 3  1960           NaN                      Albania   NaN
# 4  1960  2.723615e+09                      Algeria   NaN
#
#    Part terres agricoles  Part terres foret
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4                    NaN                NaN

# %%
merged_data
# Out:
#       date           PIB                      country  GINI  \
# 0     2010  1.585667e+10                  Afghanistan   NaN
# 1     2010  8.494097e+11  Africa Eastern and Southern   NaN
# 2     2010  5.986977e+11   Africa Western and Central   NaN
# 3     2010  1.192693e+10                      Albania   NaN
# 4     2010  1.777851e+11                      Algeria   NaN
# ...    ...           ...                          ...   ...
# 2921  2020  1.553170e+10           West Bank and Gaza   NaN
# 2922  2020  8.557772e+13                        World   NaN
# 2923  2020           NaN                  Yemen, Rep.   NaN
# 2924  2020  1.813776e+10                       Zambia   NaN
# 2925  2020  2.150970e+10                     Zimbabwe   NaN
#
#       Part terres agricoles  Part terres foret
# 0                 58.134400           1.852782
# 1                 45.629133          32.583415
# 2                 38.756043          20.674012
# 3                 43.843066          28.542701
# 4                 17.371334           0.805294
# ...                     ...                ...
# 2921              67.751429           1.684385
# 2922              36.730920          31.176905
# 2923              44.419190           1.039832
# 2924              32.067959          60.283337
# 2925              41.876696          45.093912
#
# [2926 rows x 6 columns]
