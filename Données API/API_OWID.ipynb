# %%
import pandas as pd
## faire un: pip install owid-catalog
from owid import catalog
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
results = catalog.find("tree")
df = results.iloc[0].load()
df
# Out:
#                   commodity_driven_deforestation     forestry  \
# country     year
# Afghanistan 2001                            <NA>     31.75351
#             2002                            <NA>    67.850754
#             2003                            <NA>   113.221039
#             2004                            <NA>   131.220551
#             2005                            <NA>   102.621201
# ...                                          ...          ...
# Zimbabwe    2019                        1.382205  6526.898438
#             2020                        1.017816  2693.831543
#             2021                        1.600864  2937.024658
#             2022                        4.023651  3659.499756
#             2023                        4.559243  1984.676147
#
#                   shifting_agriculture     unknown  urbanization   wildfire  \
# country     year
# Afghanistan 2001                  <NA>   56.339203          <NA>       <NA>
# ...

# %%
ligne= df.loc["France"]
ligne
# Out:
#       commodity_driven_deforestation       forestry  shifting_agriculture  \
# year
# 2001                            <NA>   32516.966797             75.789345
# 2002                            <NA>   32730.068359             81.617653
# 2003                            <NA>     24546.8125             82.225327
# 2004                            <NA>   73151.710938            183.336044
# 2005                            <NA>   44690.726562            140.642944
# 2006                            <NA>   52741.191406            170.591614
# 2007                            <NA>   47489.636719            154.953506
# 2008                            <NA>   83373.460938            147.269287
# 2009                            <NA>   65074.363281            121.662506
# 2010                            <NA>      140902.75            177.021133
# 2011                            <NA>   62458.890625            141.986847
# 2012                            <NA>   65111.136719            179.600418
# ...
